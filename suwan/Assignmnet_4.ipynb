# %% [markdown]
# # 과제4
#
# inactive 사용자만 따로 inactive_users dict로 모아보기(새 컬렉션 전략) 구현해줘.

# %%
users = {"Hans": "active", "Éléonore": "inactive", "Ken": "active"}

inactive_users = {name:status for name,status in users.items() if status =="inactive"}

print("active users:", users)
print("inactive users:", inactive_users)
# Out:
# active users: {'Hans': 'active', 'Éléonore': 'inactive', 'Ken': 'active'}
# inactive users: {'Éléonore': 'inactive'}
