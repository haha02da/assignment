# %% [markdown]
# ## 과제7

# %%
import random

# %%
answer=random.sample(range(1,21),1)[0]

# %%
print(answer)
# Out:
# 4

# %%
type(answer)
# Out:
# int

# %%
a=int(input('select num between 1~20'))

# %%
for i in range(5):
    a=input('select num between 1~20')
    if a == answer:
        print('corret')
        break
if a != answer:
    print('lose')
# Out:
# lose
